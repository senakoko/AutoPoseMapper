# %% [markdown]
# # DEMO TO USE ID Tracker.AI FUNCTIONS

# %% [markdown]
# This notebook is to use ID tracker functions. It assumes you created the trajectories.npy files with ID Tracker and copied them to the respective folders

# %%
import sys

sys.path.append('/Users/senaagezo/PycharmProjects/AutoPoseMapper/')

# %%
from autoposemapper.id_tracker_tools import IdTracker
from autoposemapper.auxiliary_tools import utils as AX_utils

# %%
project_path = '/Users/senaagezo/Downloads/AutoTest-Sena-2022-04-17/'

# %%
idtracker = IdTracker(project_path)

# %% [markdown]
# ### Make h5 files from the numpy trajectories

# %%
idtracker.make_h5s_id_trajectories()
# Out:
# Cohab1_pre_20211025_124326434_idtraj.h5

# %% [markdown]
# ### Check h5 files

# %%
file_path = '/Users/senaagezo/Downloads/AutoTest-Sena-2022-04-17/id_tracker_data/Cohab1_pre_20211025_124326434/Cohab1_pre_20211025_124326434_idtraj.h5'

# %%
h5 = AX_utils.check_pandas_h5(file_path)
h5
# Out:
# scorer       ID_Tracker
# individuals        ind1                     ind2
# bodyparts        Center                   Center
# coords                x            y           x            y
# 0            637.600231  1248.415696  372.222694  1205.708972
# 1            633.690079  1249.105012  371.623325  1203.357038
# 2            631.030767  1246.916287  373.395720  1200.115293
# 3                   NaN          NaN         NaN          NaN
# 4                   NaN          NaN         NaN          NaN
# ...                 ...          ...         ...          ...
# 54728        372.729207   351.135315  584.306036  1228.810530
# 54729        372.729207   351.135315  584.306036  1228.810530
# 54730        372.729207   351.135315  584.306036  1228.810530
# 54731        372.729207   351.135315  584.306036  1228.810530
# 54732        372.729859   351.138618  584.296657  1228.793186
#
# [54733 rows x 4 columns]

# %% [markdown]
# ### Create new centroid based on IDTracker and Autoencoder

# %% [markdown]
# ##### Path to the h5 files created by the autoencoder. You want the parent path

# %%
auto_source_path = '/Users/senaagezo/Downloads/AutoTest-Sena-2022-04-17/autoencoder_data/'

# %%
idtracker.create_csi_centroid(auto_source_path=auto_source_path)
# Out:
# provide the name of file to use to look up coordinate information if needed
# /Users/senaagezo/Downloads/AutoTest-Sena-2022-04-17/id_tracker_data/Cohab1_pre_20211025_124326434/Cohab1_pre_20211025_124326434_idtraj.h5
# 100%|█████████████████████████████████████████████████████████████████████████████| 54733/54733 [00:00<00:00, 168397.35it/s]

# %% [markdown]
# ### Swap tracked points based on labels

# %%
idtracker.create_labels_based_on_csi(auto_source_path=auto_source_path)
# Out:
# /Users/senaagezo/Downloads/AutoTest-Sena-2022-04-17/id_tracker_data/Cohab1_pre_20211025_124326434/Cohab1_pre_20211025_124326434_CSI_centroid.h5
# /Users/senaagezo/Downloads/AutoTest-Sena-2022-04-17/autoencoder_data/Cohab1_pre_20211025_124326434/Cohab1_pre_20211025_124326434_CNN_SAE.h5
# 100%|██████████████████████████████████████████████████████████████████████████████| 54733/54733 [00:04<00:00, 11624.81it/s]
# 100%|██████████████████████████████████████████████████████████████████████████████| 54733/54733 [00:04<00:00, 11681.73it/s]
# /Users/senaagezo/Downloads/AutoTest-Sena-2022-04-17/id_tracker_data/Cohab1_pre_20211025_124326434/Cohab1_pre_20211025_124326434_labels.h5

# %%
idtracker.swap_tracks_based_on_labels(auto_source_path=auto_source_path)
# Out:
# /Users/senaagezo/Downloads/AutoTest-Sena-2022-04-17/id_tracker_data/Cohab1_pre_20211025_124326434/Cohab1_pre_20211025_124326434_labels.h5
# 2it [00:05,  2.66s/it]
# /Users/senaagezo/Downloads/AutoTest-Sena-2022-04-17/autoencoder_data/Cohab1_pre_20211025_124326434/Cohab1_pre_20211025_124326434_CSI_filtered.h5

# %%
file_path2 = '/Users/senaagezo/Downloads/AutoTest-Sena-2022-04-17/autoencoder_data/Cohab1_pre_20211025_124326434/Cohab1_pre_20211025_124326434_CSI_filtered.h5'

# %%
h5 = AX_utils.check_pandas_h5(file_path2)
h5
# Out:
# scorer      CSI_filtered               ...
# individuals         ind1               ...            ind2
# bodyparts           Nose               ... midHip_rightHip
# coords                 x            y  ...               x            y
# 0             438.582455  1342.469833  ...      626.866545  1341.517120
# 1             438.582455  1342.469833  ...      626.866545  1341.517120
# 2             461.225708  1313.050346  ...      638.861777  1340.845024
# 3             467.073738  1309.713501  ...      629.711914  1339.416595
# 4             503.526802  1305.274010  ...      631.671787  1340.646767
# ...                  ...          ...  ...             ...          ...
# 54728         336.178116   475.237061  ...      473.307739  1241.456018
# 54729         336.178188   475.237061  ...      473.307632  1241.455820
# 54730         336.178116   475.237061  ...      473.307739  1241.456018
# 54731         336.178188   475.237061  ...      473.307632  1241.455820
# 54732         336.177296   475.250053  ...      473.323021  1241.451736
#
# [54733 rows x 84 columns]

# %% [markdown]
# ### Fix Bad Areas in H5 files

# %%
idtracker.fix_bad_areas_h5()
# Out:
# /Users/senaagezo/Downloads/AutoTest-Sena-2022-04-17/autoencoder_data/Cohab1_pre_20211025_124326434/Cohab1_pre_20211025_124326434_CSI_Area_filtered.h5
# 100%|█████████████████████████████████████████████████████████████████████████████| 54733/54733 [00:00<00:00, 191722.06it/s]
# 100%|█████████████████████████████████████████████████████████████████████████████| 54733/54733 [00:00<00:00, 182884.63it/s]

# %% [markdown]
# ### Create Individual Animals from Multi-Animal Dataset

# %%
idtracker.create_ind_from_multi(encoder_type='CSI_Area')
# Out:
# /Users/senaagezo/Downloads/AutoTest-Sena-2022-04-17/autoencoder_data/Cohab1_pre_20211025_124326434/Cohab1_pre_20211025_124326434_CSI_Area_filtered.h5
# 2it [00:00, 24.50it/s]
